# %%
# !git clone https://github.com/iamdrzazgowski/weather-forecast.git /content/weather-forecast
# Out:
# Cloning into '/content/weather-forecast'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 7 (delta 0), reused 7 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (7/7), done.

# %%
import os

print(os.listdir("/content/weather-forecast"))
# Out:
# ['requirements.txt', 'src', 'notebooks', '.git']

# %%
import sys

sys.path.insert(0, "/content/weather-forecast")

from src.test_model import get_device, gpu_info

print("Device:", get_device())
print("GPU:", gpu_info())
# Out:
# Device: cuda
# GPU: Tesla T4
